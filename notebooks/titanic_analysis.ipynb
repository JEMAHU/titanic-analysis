# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Cargar datos
train = pd.read_csv('../data/train_original.csv')
test = pd.read_csv('../data/test_original.csv')

# 1. Análisis de Supervivencia
sns.countplot(x='Survived', data=train)
plt.title('Distribución de Supervivencia')
plt.show()

# 2. Correlación entre variables
#plt.figure(figsize=(10, 6))
#sns.heatmap(train.corr(), annot=True, cmap='coolwarm')
#plt.title('Mapa de Correlación')
#plt.show()

# 3. Distribución de Edades por Clase
sns.boxplot(x='Pclass', y='Age', hue='Survived', data=train)
plt.title('Edad vs. Clase y Supervivencia')
plt.show()
